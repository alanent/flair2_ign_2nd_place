# %% [markdown]
# # Script d'inference
# ---
# <a target="_blank" href="https://colab.research.google.com/drive/1FxU8SOoghUwyI-Eza_gPWllHSXyVok5k">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# https://huggingface.co/docs/transformers/model_doc/segformer

# %% [markdown]
# ## Connect do GoogleDrive
#
# ---

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## Install dependencies
#
# ---

# %%
# %%capture
! pip install split-folders
! pip install evaluate
! pip install rasterio
! pip install onnx
! pip install onnxruntime-gpu
! pip install --quiet bitsandbytes
! pip install --quiet --upgrade transformers # Install latest version of transformers
! pip install --quiet --upgrade accelerate
! pip install onnxconverter-common

# %%
import accelerate
import transformers
import torch

print(transformers.__version__, accelerate.__version__)
print(torch.__version__)

from torch.utils.data import Dataset, DataLoader
from transformers import AdamW
from torch import nn
from sklearn.metrics import accuracy_score
from tqdm.notebook import tqdm
import os
from PIL import Image
from transformers import SegformerForSemanticSegmentation, SegformerImageProcessor,SegformerFeatureExtractor
import pandas as pd
import cv2
import numpy as np
import albumentations as aug
import random
import rasterio
from pathlib import Path
import splitfolders
import shutil
import math
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import backend as K
import time
from torch.nn.functional import interpolate
import onnx
from onnxconverter_common import auto_mixed_precision, auto_convert_mixed_precision, float16
# Out:
# 4.33.3 0.23.0
# 2.0.1+cu118

# %% [markdown]
# ## Check GPU Ressources
#
# ---

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Sep 29 06:54:23 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    12W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Unzip training data
#
# ---

# %%
# %%capture
# !unzip /content/gdrive/MyDrive/FLAIR2/flair_2_dataset/flair_2_aerial_test.zip
# !unzip /content/gdrive/MyDrive/FLAIR2/flair_2_dataset/sentinel_mean_test.zip

# %% [markdown]
# ## Split data for train/val
#
# ---

# %%
! mkdir "/content/temp"

# Chemin du dossier de destination
dst_folder = '/content/temp/'

# Chemin du dossier source
src_folder = '/content/flair_2_aerial_test'
for subdir, dirs, files in os.walk(src_folder):
    for file in files:
        src_file = os.path.join(subdir, file)
        dst_file = os.path.join(dst_folder, file)
        shutil.move(src_file, dst_folder)


# Chemin du dossier source
src_folder = 'content/data/sentinel'
for subdir, dirs, files in os.walk(src_folder):
    for file in files:
        src_file = os.path.join(subdir, file)
        dst_file = os.path.join(dst_folder, file)
        shutil.move(src_file, dst_folder)

# %% [markdown]
# # Chargement et conversion des modèles
#
# ---

# %%
# CUDA DEVICE
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %%
# load LABEL DICT AND FEATURE EXTRACTOR
def array_to_dict(array):
    dictionary = {}
    for i, item in enumerate(array):
        dictionary[i] = item
    return dictionary

classes = ['None','building','pervious surface','impervious surface','bare soil','water','coniferous','deciduous','brushwood','vineyard','herbaceous vegetation','agricultural land','plowed land']
id2label = array_to_dict(classes)
label2id = {v: k for k, v in id2label.items()}

num_labels = len(id2label)

feature_extractor = SegformerFeatureExtractor(ignore_index=0, reduce_labels=False, do_resize=False, do_rescale=False, do_normalize=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/segformer/feature_extraction_segformer.py:28: FutureWarning: The class SegformerFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use SegformerImageProcessor instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/models/segformer/image_processing_segformer.py:101: FutureWarning: The `reduce_labels` parameter is deprecated and will be removed in a future version. Please use `do_reduce_labels` instead.
#   warnings.warn(
# device(type='cuda')

# %%
pretrained_model_name_b5_sentinel_norm =  "/content/gdrive/MyDrive/FLAIR2/models/segformer_b5_rgb_norm_sentinel2-4e" #@param {type:"string"}
model_b5_sentinel_norm = SegformerForSemanticSegmentation.from_pretrained(
    pretrained_model_name_b5_sentinel_norm,
    id2label=id2label,
    label2id=label2id,
    reshape_last_stage=True,
    ignore_mismatched_sizes=True
)

model_b5_sentinel_norm  = model_b5_sentinel_norm.to(device)
dummy_input = torch.randn(1, 3, 512, 512, device="cuda")
torch.onnx.export(model_b5_sentinel_norm, dummy_input, "model_b5_sentinel_norm.onnx", verbose=True)
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
pretrained_model_name_b5_igb_norm =  "/content/gdrive/MyDrive/FLAIR2/models/segformer_b5_igb_norm_aerial-8e+psdl" #@param {type:"string"}
model_b5_igb_norm = SegformerForSemanticSegmentation.from_pretrained(
    pretrained_model_name_b5_igb_norm,
    id2label=id2label,
    label2id=label2id,
    reshape_last_stage=True,
    ignore_mismatched_sizes=True
)

model_b5_igb_norm  = model_b5_igb_norm.to(device)
dummy_input = torch.randn(1, 3, 512, 512, device="cuda")
torch.onnx.export(model_b5_igb_norm, dummy_input, "model_b5_igb_norm.onnx", verbose=True)
# Out:
# ============= Diagnostic Run torch.onnx.export version 2.0.1+cu118 =============
# verbose: False, log level: Level.ERROR
# ======================= 0 NONE 0 NOTE 0 WARNING 0 ERROR ========================

# %%
# %%capture
#CONVERT TO ONNX FLOAT 16 // REDUCE THE SIZE OF THE MODEL BY 2

model = onnx.load("model_b5_sentinel_norm.onnx")
model_fp16 = float16.convert_float_to_float16(model)
onnx.save(model_fp16, "model_b5_sentinel_norm_fp16.onnx")

model = onnx.load("model_b5_igb_norm.onnx")
model_fp16 = float16.convert_float_to_float16(model)
onnx.save(model_fp16, "model_b5_igb_norm_fp16.onnx")

# %%
# Spécifiez les fournisseurs d'exécution que vous souhaitez utiliser
providers = ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']

# %%
import onnxruntime as ort
ort.get_device()
# Out:
# 'GPU'

# %%
ort_session_b5_sentinel_norm = ort.InferenceSession("model_b5_sentinel_norm_fp16.onnx", providers=providers)
ort_session_b5_igb_norm = ort.InferenceSession("model_b5_igb_norm_fp16.onnx", providers=providers)
# Out:
# EP Error /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1193 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_tensorrt.so with error: libnvinfer.so.8: cannot open shared object file: No such file or directory
#  when using ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CUDAExecutionProvider', 'CPUExecutionProvider'] and retrying.
# EP Error /onnxruntime_src/onnxruntime/core/session/provider_bridge_ort.cc:1193 onnxruntime::Provider& onnxruntime::ProviderLibrary::Get() [ONNXRuntimeError] : 1 : FAIL : Failed to load library libonnxruntime_providers_tensorrt.so with error: libnvinfer.so.8: cannot open shared object file: No such file or directory
#  when using ['TensorrtExecutionProvider', 'CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CUDAExecutionProvider', 'CPUExecutionProvider'] and retrying.

# %%
# !mkdir preds

def lister_images(dossier):
    chemins_images = []
    noms_images = []

    for dossier_racine, sous_dossiers, fichiers in os.walk(dossier):
        for fichier in fichiers:
            # Vérifie si le fichier se termine par ".tif"
            if fichier.endswith(".tif"):
                chemin_image = os.path.join(dossier_racine, fichier)
                nom_image = fichier

                chemins_images.append(chemin_image)
                noms_images.append(nom_image)

    return chemins_images, noms_images


# Spécifiez le chemin du dossier contenant les images
dossier_images = "/content/temp"

# Obtenez la liste des chemins et noms d'images
chemins, noms = lister_images(dossier_images)

# %% [markdown]
# # Inference
#
# ---

# %%
debut = time.time()
ix=0
for chemin, nom in zip(chemins, noms):
    if ix % 400 == 0:
        fin = time.time()
        temps_execution = int(fin - debut)
        print("nombre d'executions : ", ix, f" // temps d'execution : {temps_execution} secondes")

    ix= ix+1



    # get raster file
    with rasterio.open(chemin) as src_img:
        image = src_img.read([1,2,3]).swapaxes(0, 2).swapaxes(0, 1)
        igb = src_img.read([4,2,3]).swapaxes(0, 2).swapaxes(0, 1)
        igb = igb.astype(np.float32)

    # aerial igb normalization
    MEAN = np.array([ 0.40987858, 0.45704361, 0.42254708])
    STD = np.array([ 0.15510736, 0.1782405 , 0.17575739])
    igb_norm = aug.Compose([aug.Normalize(mean=MEAN, std=STD)])
    image_igb_norm = igb_norm(image=igb)['image']


    # sentinel normalization
    sen = np.load('/content/temp/'+ nom.replace('IMG','SEN').replace('tif','npy'))

    #get MEAN and STD for normalization
    MEAN = np.mean(sen.squeeze(), axis=(1, 2))
    STD= np.std(sen.squeeze(), axis=(1, 2))

    #Check for NaN values
    nan_present = any(math.isnan(x) for x in MEAN)
    if nan_present:
        MEAN = np.array([0.44050665, 0.45704361, 0.42254708])
        STD = np.array([0.20264351, 0.1782405 , 0.17575739])
    sentinel_norm = aug.Compose([aug.Normalize(mean=MEAN, std=STD)])
    image_sentinel_norm = sentinel_norm(image=image)['image']

    pixel_values_sentinel_norm = feature_extractor(image_sentinel_norm, return_tensors="np").pixel_values.astype(np.float16) #.to(device)
    pixel_values_igb_norm = feature_extractor(image_igb_norm, return_tensors="np").pixel_values.astype(np.float16) #.to(device)


    # image_np = pixel_values.cpu().numpy()
    output_b5_sentinel_norm = ort_session_b5_sentinel_norm.run(None,  {"input.1":pixel_values_sentinel_norm})[0]
    output_b5_igb_norm = ort_session_b5_igb_norm.run(None,  {"input.1":pixel_values_igb_norm})[0]


    ######################################################################################################
    # aggregate results predictions
    pred_segformer_b5_igb_norm = tf.image.resize(tf.transpose(output_b5_igb_norm, perm=[0,2,3,1]), size = [512,512], method="bilinear") # resize to 512*512
    pred_segformer_b5_sentinel_norm = tf.image.resize(tf.transpose(output_b5_sentinel_norm, perm=[0,2,3,1]), size = [512,512], method="bilinear") # resize to 512*512


    preds = np.mean(np.array([ pred_segformer_b5_igb_norm,pred_segformer_b5_sentinel_norm  ]), axis = 0)
    preds = [np.argmax(preds[index,:,:,:], axis = -1).transpose((0,1)) for index in range(preds.shape[0])]
    preds = np.squeeze(preds)
    preds = np.array(preds)-1
    preds = preds.astype('uint8')  # Pass prediction on CPU


    preds_sent = np.mean(np.array([pred_segformer_b5_sentinel_norm]), axis = 0)
    preds_sent = [np.argmax(preds_sent[index,:,:,:], axis = -1).transpose((0,1)) for index in range(preds_sent.shape[0])]
    preds_sent =np.squeeze(preds_sent)
    preds_sent = np.array(preds_sent)-1
    preds_sent = preds_sent.astype('uint8')  # Pass prediction on CPU

    preds_igb = np.mean(np.array([pred_segformer_b5_igb_norm]), axis = 0)
    preds_igb  = [np.argmax(preds_igb [index,:,:,:], axis = -1).transpose((0,1)) for index in range(preds_igb.shape[0])]
    preds_igb  =np.squeeze(preds_igb )
    preds_igb  = np.array(preds_igb )-1
    preds_igb  = preds_igb.astype('uint8')  # Pass prediction on CPU

    preds[preds == 5] = preds_igb[preds == 5]
    preds[preds == 8] = preds_sent[preds == 8]
    preds[preds == 9] = preds_igb[preds == 9]
    preds[preds == 10] = preds_igb[preds == 10]
    preds[preds == 11] = preds_igb[preds == 11]


    chemin_sortie = "/content/preds/" + nom.split('/')[-1].replace('IMG', 'PRED')
    Image.fromarray(preds).save(chemin_sortie, compression='tiff_lzw')

fin = time.time()
temps_execution = int((fin - debut)/60)

print(f" Temps total d'execution : {temps_execution} minutes")
# Out:
# nombre d'executions :  0  // temps d'execution : 0 secondes
# nombre d'executions :  400  // temps d'execution : 67 secondes
# nombre d'executions :  800  // temps d'execution : 134 secondes
# nombre d'executions :  1200  // temps d'execution : 201 secondes
# nombre d'executions :  1600  // temps d'execution : 270 secondes
# nombre d'executions :  2000  // temps d'execution : 339 secondes
# nombre d'executions :  2400  // temps d'execution : 408 secondes
# nombre d'executions :  2800  // temps d'execution : 477 secondes
# nombre d'executions :  3200  // temps d'execution : 546 secondes
# nombre d'executions :  3600  // temps d'execution : 616 secondes
# nombre d'executions :  4000  // temps d'execution : 685 secondes
# nombre d'executions :  4400  // temps d'execution : 754 secondes
# nombre d'executions :  4800  // temps d'execution : 823 secondes
# nombre d'executions :  5200  // temps d'execution : 892 secondes
# nombre d'executions :  5600  // temps d'execution : 961 secondes
# nombre d'executions :  6000  // temps d'execution : 1030 secondes
# nombre d'executions :  6400  // temps d'execution : 1099 secondes
# nombre d'executions :  6800  // temps d'execution : 1168 secondes
# nombre d'executions :  7200  // temps d'execution : 1237 secondes
# nombre d'executions :  7600  // temps d'execution : 1307 secondes
# nombre d'executions :  8000  // temps d'execution : 1376 secondes
# nombre d'executions :  8400  // temps d'execution : 1446 secondes
# nombre d'executions :  8800  // temps d'execution : 1516 secondes
# nombre d'executions :  9200  // temps d'execution : 1585 secondes
# nombre d'executions :  9600  // temps d'execution : 1655 secondes
# nombre d'executions :  10000  // temps d'execution : 1725 secondes
# nombre d'executions :  10400  // temps d'execution : 1794 secondes
# nombre d'executions :  10800  // temps d'execution : 1864 secondes
# nombre d'executions :  11200  // temps d'execution : 1933 secondes
# nombre d'executions :  11600  // temps d'execution : 2003 secondes
# nombre d'executions :  12000  // temps d'execution : 2073 secondes
# nombre d'executions :  12400  // temps d'execution : 2142 secondes
# nombre d'executions :  12800  // temps d'execution : 2212 secondes
# nombre d'executions :  13200  // temps d'execution : 2282 secondes
# nombre d'executions :  13600  // temps d'execution : 2351 secondes
# nombre d'executions :  14000  // temps d'execution : 2421 secondes
# nombre d'executions :  14400  // temps d'execution : 2491 secondes
# nombre d'executions :  14800  // temps d'execution : 2561 secondes
# nombre d'executions :  15200  // temps d'execution : 2631 secondes
# nombre d'executions :  15600  // temps d'execution : 2701 secondes
# nombre d'executions :  16000  // temps d'execution : 2771 secondes
#  Temps total d'execution : 46 minutes

# %% [markdown]
# # Export results
#
# ---

# %%
# !zip -r /content/gdrive/MyDrive/FLAIR2/outputs/flair2_T4_46_min_6355_iou.zip /content/preds
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   adding: content/preds/PRED_083287.tif (deflated 2%)
#   adding: content/preds/PRED_092974.tif (deflated 4%)
#   adding: content/preds/PRED_085507.tif (deflated 13%)
#   adding: content/preds/PRED_090822.tif (deflated 15%)
#   adding: content/preds/PRED_085935.tif (deflated 10%)
#   adding: content/preds/PRED_080977.tif (deflated 30%)
#   adding: content/preds/PRED_078967.tif (deflated 1%)
#   adding: content/preds/PRED_091052.tif (deflated 28%)
#   adding: content/preds/PRED_078043.tif (deflated 8%)
#   adding: content/preds/PRED_081110.tif (deflated 1%)
#   adding: content/preds/PRED_089492.tif (deflated 2%)
#   adding: content/preds/PRED_081527.tif (deflated 16%)
#   adding: content/preds/PRED_087222.tif (deflated 71%)
#   adding: content/preds/PRED_091865.tif (deflated 71%)
#   adding: content/preds/PRED_087282.tif (deflated 71%)
#   adding: content/preds/PRED_083059.tif (deflated 71%)
#   adding: content/preds/PRED_085168.tif (deflated 61%)
#   adding: content/preds/PRED_089694.tif (deflated 71%)
#   adding: content/preds/PRED_084504.tif (deflated 1%)
#   adding: content/preds/PRED_080644.tif (deflated 3%)
#   adding: content/preds/PRED_080343.tif (deflated 4%)
#   adding: content/preds/PRED_091545.tif (deflated 2%)
#   adding: content/preds/PRED_079942.tif (deflated 1%)
#   adding: content/preds/PRED_091754.tif (deflated 2%)
#   adding: content/preds/PRED_086830.tif (deflated 1%)
#   adding: content/preds/PRED_092236.tif (deflated 2%)
#   adding: content/preds/PRED_084246.tif (deflated 1%)
#   adding: content/preds/PRED_079286.tif (deflated 1%)
#   adding: content/preds/PRED_081452.tif (deflated 2%)
#   adding: content/preds/PRED_077913.tif (deflated 2%)
#   adding: content/preds/PRED_083581.tif (deflated 3%)
#   adding: content/preds/PRED_083225.tif (deflated 4%)
#   adding: content/preds/PRED_084025.tif (deflated 24%)
#   adding: content/preds/PRED_092760.tif (deflated 3%)
#   adding: content/preds/PRED_084135.tif (deflated 2%)
#   adding: content/preds/PRED_077505.tif (deflated 3%)
#   adding: content/preds/PRED_088389.tif (deflated 5%)
#   adding: content/preds/PRED_082809.tif (deflated 1%)
#   adding: content/preds/PRED_083933.tif (deflated 5%)
#   adding: content/preds/PRED_088741.tif (deflated 71%)
#   adding: content/preds/PRED_086463.tif (deflated 2%)
#   adding: content/preds/PRED_082447.tif (deflated 9%)
#   adding: content/preds/PRED_091137.tif (deflated 5%)
#   adding: content/preds/PRED_091822.tif (deflated 7%)
#   adding: content/preds/PRED_092720.tif (deflated 0%)
#   adding: content/preds/PRED_082523.tif (deflated 71%)
#   adding: content/preds/PRED_081289.tif (deflated 2%)
#   adding: content/preds/PRED_077432.tif (deflated 1%)
#   adding: content/preds/PRED_081256.tif (deflated 9%)
#   adding: content/preds/PRED_081012.tif (deflated 2%)
#   adding: content/preds/PRED_080718.tif (deflated 1%)
#   adding: content/preds/PRED_078005.tif (deflated 13%)
#   adding: content/preds/PRED_091378.tif (deflated 71%)
#   adding: content/preds/PRED_091439.tif (deflated 71%)
#   adding: content/preds/PRED_089270.tif (deflated 26%)
#   adding: content/preds/PRED_083212.tif (deflated 23%)
#   adding: content/preds/PRED_090757.tif (deflated 25%)
#   adding: content/preds/PRED_079668.tif (deflated 3%)
#   adding: content/preds/PRED_080788.tif (deflated 3%)
#   adding: content/preds/PRED_079591.tif (deflated 3%)
#   adding: content/preds/PRED_090500.tif (deflated 2%)
#   adding: content/preds/PRED_089556.tif (deflated 71%)
#   adding: content/preds/PRED_079432.tif (deflated 64%)
#   adding: content/preds/PRED_093416.tif (deflated 0%)
#   adding: content/preds/PRED_090815.tif (deflated 30%)
#   adding: content/preds/PRED_085111.tif (deflated 41%)
#   adding: content/preds/PRED_078793.tif (deflated 1%)
#   adding: content/preds/PRED_089782.tif (deflated 41%)
#   adding: content/preds/PRED_083099.tif (deflated 1%)
#   adding: content/preds/PRED_082430.tif (deflated 1%)
#   adding: content/preds/PRED_081544.tif (deflated 1%)
#   adding: content/preds/PRED_085451.tif (deflated 2%)
#   adding: content/preds/PRED_083542.tif (deflated 52%)
#   adding: content/preds/PRED_089555.tif (deflated 7%)
#   adding: content/preds/PRED_077747.tif (deflated 2%)
#   adding: content/preds/PRED_092782.tif (deflated 1%)
#   adding: content/preds/PRED_077572.tif (deflated 1%)
#   adding: content/preds/PRED_077655.tif (deflated 71%)
#   adding: content/preds/PRED_085365.tif (deflated 14%)
#   adding: content/preds/PRED_083368.tif (deflated 2%)
#   adding: content/preds/PRED_085008.tif (deflated 2%)
#   adding: content/preds/PRED_087371.tif (deflated 3%)
#   adding: content/preds/PRED_084576.tif (deflated 71%)
#   adding: content/preds/PRED_091266.tif (deflated 2%)
#   adding: content/preds/PRED_083318.tif (deflated 17%)
#   adding: content/preds/PRED_077877.tif (deflated 1%)
#   adding: content/preds/PRED_087487.tif (deflated 2%)
#   adding: content/preds/PRED_082261.tif (deflated 42%)
#   adding: content/preds/PRED_084809.tif (deflated 1%)
#   adding: content/preds/PRED_078642.tif (deflated 2%)
#   adding: content/preds/PRED_085628.tif (deflated 71%)
#   adding: content/preds/PRED_081049.tif (deflated 0%)
#   adding: content/preds/PRED_087679.tif (deflated 18%)
#   adding: content/preds/PRED_083096.tif (deflated 5%)
#   adding: content/preds/PRED_077418.tif (deflated 3%)
#   adding: content/preds/PRED_084874.tif (deflated 1%)
#   adding: content/preds/PRED_079358.tif (deflated 7%)
#   adding: content/preds/PRED_083314.tif (deflated 18%)
#   adding: content/preds/PRED_082514.tif (deflated 1%)
#   adding: content/preds/PRED_086364.tif (deflated 1%)
#   adding: content/preds/PRED_090200.tif (deflated 2%)
#   adding: content/preds/PRED_085132.tif (deflated 0%)
#   adding: content/preds/PRED_091217.tif (deflated 71%)
#   adding: content/preds/PRED_092165.tif (deflated 1%)
#   adding: content/preds/PRED_085629.tif (deflated 12%)
#   adding: content/preds/PRED_088898.tif (deflated 70%)
#   adding: content/preds/PRED_080192.tif (deflated 22%)
#   adding: content/preds/PRED_082936.tif (deflated 1%)
#   adding: content/preds/PRED_080211.tif (deflated 22%)
#   adding: content/preds/PRED_085537.tif (deflated 1%)
#   adding: content/preds/PRED_083809.tif (deflated 5%)
#   adding: content/preds/PRED_085594.tif (deflated 5%)
#   adding: content/preds/PRED_091593.tif (deflated 35%)
#   adding: content/preds/PRED_082834.tif (deflated 1%)
#   adding: content/preds/PRED_084225.tif (deflated 4%)
#   adding: content/preds/PRED_089275.tif (deflated 71%)
#   adding: content/preds/PRED_077978.tif (deflated 2%)
#   adding: content/preds/PRED_089039.tif (deflated 3%)
#   adding: content/preds/PRED_088323.tif (deflated 1%)
#   adding: content/preds/PRED_086114.tif (deflated 5%)
#   adding: content/preds/PRED_086619.tif (deflated 1%)
#   adding: content/preds/PRED_089000.tif (deflated 1%)
#   adding: content/preds/PRED_092164.tif (deflated 2%)
#   adding: content/preds/PRED_093141.tif (deflated 1%)
#   adding: content/preds/PRED_080966.tif (deflated 71%)
#   adding: content/preds/PRED_085843.tif (deflated 6%)
#   adding: content/preds/PRED_086346.tif (deflated 1%)
#   adding: content/preds/PRED_078434.tif (deflated 71%)
#   adding: content/preds/PRED_079030.tif (deflated 1%)
#   adding: content/preds/PRED_081486.tif (deflated 3%)
#   adding: content/preds/PRED_084942.tif (deflated 2%)
#   adding: content/preds/PRED_079940.tif (deflated 1%)
#   adding: content/preds/PRED_079376.tif (deflated 3%)
#   adding: content/preds/PRED_083545.tif (deflated 71%)
#   adding: content/preds/PRED_081524.tif (deflated 1%)
#   adding: content/preds/PRED_090337.tif (deflated 4%)
#   adding: content/preds/PRED_087453.tif (deflated 18%)
#   adding: content/preds/PRED_085119.tif (deflated 4%)
#   adding: content/preds/PRED_080096.tif (deflated 2%)
#   adding: content/preds/PRED_082393.tif (deflated 3%)
#   adding: content/preds/PRED_078002.tif (deflated 4%)
#   adding: content/preds/PRED_081498.tif (deflated 71%)
#   adding: content/preds/PRED_078827.tif (deflated 1%)
#   adding: content/preds/PRED_078837.tif (deflated 2%)
#   adding: content/preds/PRED_080549.tif (deflated 19%)
#   adding: content/preds/PRED_087928.tif (deflated 60%)
#   adding: content/preds/PRED_086904.tif (deflated 1%)
#   adding: content/preds/PRED_080675.tif (deflated 3%)
#   adding: content/preds/PRED_078265.tif (deflated 3%)
#   adding: content/preds/PRED_088409.tif (deflated 6%)
#   adding: content/preds/PRED_084353.tif (deflated 2%)
#   adding: content/preds/PRED_086994.tif (deflated 5%)
#   adding: content/preds/PRED_088736.tif (deflated 1%)
#   adding: content/preds/PRED_082908.tif (deflated 1%)
#   adding: content/preds/PRED_085922.tif (deflated 3%)
#   adding: content/preds/PRED_080143.tif (deflated 33%)
#   adding: content/preds/PRED_086651.tif (deflated 1%)
#   adding: content/preds/PRED_086333.tif (deflated 71%)
#   adding: content/preds/PRED_081294.tif (deflated 10%)
#   adding: content/preds/PRED_083439.tif (deflated 17%)
#   adding: content/preds/PRED_078700.tif (deflated 1%)
#   adding: content/preds/PRED_087432.tif (deflated 49%)
#   adding: content/preds/PRED_083570.tif (deflated 12%)
#   adding: content/preds/PRED_079557.tif (deflated 8%)
#   adding: content/preds/PRED_083688.tif (deflated 24%)
#   adding: content/preds/PRED_087501.tif (deflated 54%)
#   adding: content/preds/PRED_080992.tif (deflated 0%)
#   adding: content/preds/PRED_083397.tif (deflated 71%)
#   adding: content/preds/PRED_085538.tif (deflated 3%)
#   adding: content/preds/PRED_078867.tif (deflated 0%)
#   adding: content/preds/PRED_092788.tif (deflated 8%)
#   adding: content/preds/PRED_088169.tif (deflated 3%)
#   adding: content/preds/PRED_083155.tif (deflated 4%)
#   adding: content/preds/PRED_091965.tif (deflated 4%)
#   adding: content/preds/PRED_086947.tif (deflated 1%)
#   adding: content/preds/PRED_080498.tif (deflated 5%)
#   adding: content/preds/PRED_082195.tif (deflated 71%)
#   adding: content/preds/PRED_083538.tif (deflated 3%)
#   adding: content/preds/PRED_089656.tif (deflated 8%)
#   adding: content/preds/PRED_083423.tif (deflated 2%)
#   adding: content/preds/PRED_083148.tif (deflated 43%)
#   adding: content/preds/PRED_084471.tif (deflated 24%)
#   adding: content/preds/PRED_087695.tif (deflated 1%)
#   adding: content/preds/PRED_091920.tif (deflated 1%)
#   adding: content/preds/PRED_091080.tif (deflated 1%)
#   adding: content/preds/PRED_086928.tif (deflated 2%)
#   adding: content/preds/PRED_083352.tif (deflated 7%)
#   adding: content/preds/PRED_084451.tif (deflated 71%)
#   adding: content/preds/PRED_084266.tif (deflated 24%)
#   adding: content/preds/PRED_077921.tif (deflated 11%)
#   adding: content/preds/PRED_088811.tif (deflated 51%)
#   adding: content/preds/PRED_086535.tif (deflated 7%)
#   adding: content/preds/PRED_079037.tif (deflated 1%)
#   adding: content/preds/PRED_083375.tif (deflated 6%)
#   adding: content/preds/PRED_086769.tif (deflated 1%)
#   adding: content/preds/PRED_086387.tif (deflated 3%)
#   adding: content/preds/PRED_086128.tif (deflated 71%)
#   adding: content/preds/PRED_087443.tif (deflated 5%)
#   adding: content/preds/PRED_089400.tif (deflated 7%)
#   adding: content/preds/PRED_083707.tif (deflated 6%)
#   adding: content/preds/PRED_077867.tif (deflated 1%)
#   adding: content/preds/PRED_084270.tif (deflated 7%)
#   adding: content/preds/PRED_092537.tif (deflated 2%)
#   adding: content/preds/PRED_089381.tif (deflated 32%)
#   adding: content/preds/PRED_078875.tif (deflated 1%)
#   adding: content/preds/PRED_091908.tif (deflated 3%)
#   adding: content/preds/PRED_090404.tif (deflated 2%)
#   adding: content/preds/PRED_084959.tif (deflated 1%)
#   adding: content/preds/PRED_081178.tif (deflated 5%)
#   adding: content/preds/PRED_088576.tif (deflated 1%)
#   adding: content/preds/PRED_089874.tif (deflated 2%)
#   adding: content/preds/PRED_088142.tif (deflated 5%)
#   adding: content/preds/PRED_084125.tif (deflated 1%)
#   adding: content/preds/PRED_079873.tif (deflated 71%)
#   adding: content/preds/PRED_088518.tif (deflated 1%)
#   adding: content/preds/PRED_082051.tif (deflated 5%)
#   adding: content/preds/PRED_085394.tif (deflated 17%)
#   adding: content/preds/PRED_091476.tif (deflated 2%)
#   adding: content/preds/PRED_080668.tif (deflated 3%)
#   adding: content/preds/PRED_085633.tif (deflated 1%)
#   adding: content/preds/PRED_084350.tif (deflated 2%)
#   adding: content/preds/PRED_088996.tif (deflated 3%)
#   adding: content/preds/PRED_089354.tif (deflated 3%)
#   adding: content/preds/PRED_087084.tif (deflated 2%)
#   adding: content/preds/PRED_077630.tif (deflated 2%)
#   adding: content/preds/PRED_093438.tif (deflated 0%)
#   adding: content/preds/PRED_090186.tif (deflated 41%)
#   adding: content/preds/PRED_077605.tif (deflated 2%)
#   adding: content/preds/PRED_086496.tif (deflated 3%)
#   adding: content/preds/PRED_079287.tif (deflated 1%)
#   adding: content/preds/PRED_082415.tif (deflated 2%)
#   adding: content/preds/PRED_079493.tif (deflated 15%)
#   adding: content/preds/PRED_088724.tif (deflated 1%)
#   adding: content/preds/PRED_089784.tif (deflated 7%)
#   adding: content/preds/PRED_081200.tif (deflated 1%)
#   adding: content/preds/PRED_084657.tif (deflated 3%)
#   adding: content/preds/PRED_089715.tif (deflated 71%)
#   adding: content/preds/PRED_085856.tif (deflated 1%)
#   adding: content/preds/PRED_079427.tif (deflated 10%)
#   adding: content/preds/PRED_089215.tif (deflated 43%)
#   adding: content/preds/PRED_077731.tif (deflated 8%)
#   adding: content/preds/PRED_078789.tif (deflated 71%)
#   adding: content/preds/PRED_083284.tif (deflated 27%)
#   adding: content/preds/PRED_091307.tif (deflated 7%)
#   adding: content/preds/PRED_089950.tif (deflated 2%)
#   adding: content/preds/PRED_086016.tif (deflated 1%)
#   adding: content/preds/PRED_082493.tif (deflated 5%)
#   adding: content/preds/PRED_090091.tif (deflated 2%)
#   adding: content/preds/PRED_086921.tif (deflated 1%)
#   adding: content/preds/PRED_081173.tif (deflated 12%)
#   adding: content/preds/PRED_086005.tif (deflated 10%)
#   adding: content/preds/PRED_082407.tif (deflated 5%)
#   adding: content/preds/PRED_084645.tif (deflated 5%)
#   adding: content/preds/PRED_085641.tif (deflated 1%)
#   adding: content/preds/PRED_087952.tif (deflated 70%)
#   adding: content/preds/PRED_084421.tif (deflated 71%)
#   adding: content/preds/PRED_081119.tif (deflated 1%)
#   adding: content/preds/PRED_080217.tif (deflated 7%)
#   adding: content/preds/PRED_087719.tif (deflated 11%)
#   adding: content/preds/PRED_092317.tif (deflated 1%)
#   adding: content/preds/PRED_091666.tif (deflated 3%)
#   adding: content/preds/PRED_092602.tif (deflated 1%)
#   adding: content/preds/PRED_088069.tif (deflated 1%)
#   adding: content/preds/PRED_093145.tif (deflated 1%)
#   adding: content/preds/PRED_081382.tif (deflated 1%)
#   adding: content/preds/PRED_084871.tif (deflated 1%)
#   adding: content/preds/PRED_083370.tif (deflated 9%)
#   adding: content/preds/PRED_088804.tif (deflated 38%)
#   adding: content/preds/PRED_092994.tif (deflated 0%)
#   adding: content/preds/PRED_092784.tif (deflated 0%)
#   adding: content/preds/PRED_079084.tif (deflated 2%)
#   adding: content/preds/PRED_088781.tif (deflated 1%)
#   adding: content/preds/PRED_090158.tif (deflated 10%)
#   adding: content/preds/PRED_084679.tif (deflated 12%)
#   adding: content/preds/PRED_086777.tif (deflated 0%)
#   adding: content/preds/PRED_088779.tif (deflated 1%)
#   adding: content/preds/PRED_082867.tif (deflated 2%)
#   adding: content/preds/PRED_086764.tif (deflated 3%)
#   adding: content/preds/PRED_092563.tif (deflated 44%)
#   adding: content/preds/PRED_083392.tif (deflated 25%)
#   adding: content/preds/PRED_079583.tif (deflated 2%)
#   adding: content/preds/PRED_079598.tif (deflated 4%)
#   adding: content/preds/PRED_077823.tif (deflated 6%)
#   adding: content/preds/PRED_088704.tif (deflated 1%)
#   adding: content/preds/PRED_087402.tif (deflated 18%)
#   adding: content/preds/PRED_084573.tif (deflated 1%)
#   adding: content/preds/PRED_088534.tif (deflated 3%)
#   adding: content/preds/PRED_083741.tif (deflated 27%)
#   adding: content/preds/PRED_084193.tif (deflated 4%)
#   adding: content/preds/PRED_090245.tif (deflated 3%)
#   adding: content/preds/PRED_085894.tif (deflated 34%)
#   adding: content/preds/PRED_081101.tif (deflated 1%)
#   adding: content/preds/PRED_091575.tif (deflated 5%)
#   adding: content/preds/PRED_080993.tif (deflated 0%)
#   adding: content/preds/PRED_084335.tif (deflated 2%)
#   adding: content/preds/PRED_080837.tif (deflated 71%)
#   adding: content/preds/PRED_088279.tif (deflated 4%)
#   adding: content/preds/PRED_079782.tif (deflated 18%)
#   adding: content/preds/PRED_083978.tif (deflated 14%)
#   adding: content/preds/PRED_092045.tif (deflated 6%)
#   adding: content/preds/PRED_088197.tif (deflated 1%)
#   adding: content/preds/PRED_077460.tif (deflated 3%)
#   adding: content/preds/PRED_093146.tif (deflated 3%)
#   adding: content/preds/PRED_082337.tif (deflated 0%)
#   adding: content/preds/PRED_093266.tif (deflated 0%)
#   adding: content/preds/PRED_089195.tif (deflated 29%)
#   adding: content/preds/PRED_080961.tif (deflated 0%)
#   adding: content/preds/PRED_089042.tif (deflated 2%)
#   adding: content/preds/PRED_087267.tif (deflated 71%)
#   adding: content/preds/PRED_090076.tif (deflated 27%)
#   adding: content/preds/PRED_084273.tif (deflated 3%)
#   adding: content/preds/PRED_078071.tif (deflated 4%)
#   adding: content/preds/PRED_078586.tif (deflated 71%)
#   adding: content/preds/PRED_088093.tif (deflated 2%)
#   adding: content/preds/PRED_092388.tif (deflated 46%)
#   adding: content/preds/PRED_089221.tif (deflated 35%)
#   adding: content/preds/PRED_088853.tif (deflated 1%)
#   adding: content/preds/PRED_085238.tif (deflated 24%)
#   adding: content/preds/PRED_090331.tif (deflated 20%)
#   adding: content/preds/PRED_092203.tif (deflated 3%)
#   adding: content/preds/PRED_082966.tif (deflated 1%)
#   adding: content/preds/PRED_079786.tif (deflated 4%)
#   adding: content/preds/PRED_085286.tif (deflated 2%)
#   adding: content/preds/PRED_085477.tif (deflated 45%)
#   adding: content/preds/PRED_079530.tif (deflated 21%)
#   adding: content/preds/PRED_090063.tif (deflated 1%)
#   adding: content/preds/PRED_089206.tif (deflated 71%)
#   adding: content/preds/PRED_092350.tif (deflated 3%)
#   adding: content/preds/PRED_084293.tif (deflated 2%)
#   adding: content/preds/PRED_082920.tif (deflated 3%)
#   adding: content/preds/PRED_093393.tif (deflated 2%)
#   adding: content/preds/PRED_088006.tif (deflated 71%)
#   adding: content/preds/PRED_080083.tif (deflated 7%)
#   adding: content/preds/PRED_080394.tif (deflated 21%)
#   adding: content/preds/PRED_081205.tif (deflated 1%)
#   adding: content/preds/PRED_084914.tif (deflated 0%)
#   adding: content/preds/PRED_087659.tif (deflated 3%)
#   adding: content/preds/PRED_079804.tif (deflated 47%)
#   adding: content/preds/PRED_092981.tif (deflated 1%)
#   adding: content/preds/PRED_078438.tif (deflated 6%)
# ...
#   adding: content/preds/PRED_091086.tif (deflated 4%)
#   adding: content/preds/PRED_086310.tif (deflated 3%)
#   adding: content/preds/PRED_081797.tif (deflated 2%)
#   adding: content/preds/PRED_084753.tif (deflated 3%)
#   adding: content/preds/PRED_080589.tif (deflated 4%)
#   adding: content/preds/PRED_078035.tif (deflated 3%)
#   adding: content/preds/PRED_085301.tif (deflated 3%)
#   adding: content/preds/PRED_090445.tif (deflated 24%)
#   adding: content/preds/PRED_078058.tif (deflated 3%)
#   adding: content/preds/PRED_084864.tif (deflated 1%)
#   adding: content/preds/PRED_086146.tif (deflated 3%)
#   adding: content/preds/PRED_086486.tif (deflated 71%)
#   adding: content/preds/PRED_086396.tif (deflated 4%)
#   adding: content/preds/PRED_081302.tif (deflated 1%)
#   adding: content/preds/PRED_088722.tif (deflated 1%)
#   adding: content/preds/PRED_089451.tif (deflated 11%)
#   adding: content/preds/PRED_082776.tif (deflated 5%)
#   adding: content/preds/PRED_088547.tif (deflated 3%)
#   adding: content/preds/PRED_080194.tif (deflated 1%)
#   adding: content/preds/PRED_087634.tif (deflated 2%)
#   adding: content/preds/PRED_082343.tif (deflated 1%)
#   adding: content/preds/PRED_089958.tif (deflated 71%)
#   adding: content/preds/PRED_078507.tif (deflated 3%)
#   adding: content/preds/PRED_079116.tif (deflated 1%)
#   adding: content/preds/PRED_088609.tif (deflated 31%)
#   adding: content/preds/PRED_086563.tif (deflated 1%)
#   adding: content/preds/PRED_083885.tif (deflated 2%)
#   adding: content/preds/PRED_089728.tif (deflated 53%)
#   adding: content/preds/PRED_078121.tif (deflated 36%)
#   adding: content/preds/PRED_081543.tif (deflated 3%)
#   adding: content/preds/PRED_081586.tif (deflated 3%)
#   adding: content/preds/PRED_089410.tif (deflated 71%)
#   adding: content/preds/PRED_085041.tif (deflated 1%)
#   adding: content/preds/PRED_084977.tif (deflated 1%)
#   adding: content/preds/PRED_077898.tif (deflated 21%)
#   adding: content/preds/PRED_082812.tif (deflated 0%)
#   adding: content/preds/PRED_083805.tif (deflated 17%)
#   adding: content/preds/PRED_093007.tif (deflated 71%)
#   adding: content/preds/PRED_089813.tif (deflated 1%)
#   adding: content/preds/PRED_092713.tif (deflated 6%)
#   adding: content/preds/PRED_087085.tif (deflated 1%)
#   adding: content/preds/PRED_092131.tif (deflated 1%)
#   adding: content/preds/PRED_092515.tif (deflated 1%)
#   adding: content/preds/PRED_091088.tif (deflated 5%)
#   adding: content/preds/PRED_086077.tif (deflated 4%)
#   adding: content/preds/PRED_082892.tif (deflated 1%)
#   adding: content/preds/PRED_090639.tif (deflated 5%)
#   adding: content/preds/PRED_082371.tif (deflated 0%)
#   adding: content/preds/PRED_087476.tif (deflated 3%)
#   adding: content/preds/PRED_077514.tif (deflated 1%)
#   adding: content/preds/PRED_080844.tif (deflated 0%)
#   adding: content/preds/PRED_083040.tif (deflated 4%)
#   adding: content/preds/PRED_080489.tif (deflated 14%)
#   adding: content/preds/PRED_081035.tif (deflated 2%)
#   adding: content/preds/PRED_090502.tif (deflated 3%)
#   adding: content/preds/PRED_090117.tif (deflated 4%)
#   adding: content/preds/PRED_088155.tif (deflated 1%)
#   adding: content/preds/PRED_089246.tif (deflated 71%)
#   adding: content/preds/PRED_080155.tif (deflated 0%)
#   adding: content/preds/PRED_081467.tif (deflated 30%)
#   adding: content/preds/PRED_080230.tif (deflated 18%)
#   adding: content/preds/PRED_091570.tif (deflated 1%)
#   adding: content/preds/PRED_082414.tif (deflated 3%)
#   adding: content/preds/PRED_091435.tif (deflated 41%)
#   adding: content/preds/PRED_093191.tif (deflated 1%)
#   adding: content/preds/PRED_084749.tif (deflated 1%)
#   adding: content/preds/PRED_084878.tif (deflated 1%)
#   adding: content/preds/PRED_081408.tif (deflated 1%)
#   adding: content/preds/PRED_089436.tif (deflated 2%)
#   adding: content/preds/PRED_083888.tif (deflated 5%)
#   adding: content/preds/PRED_077813.tif (deflated 64%)
#   adding: content/preds/PRED_091927.tif (deflated 5%)
#   adding: content/preds/PRED_084698.tif (deflated 2%)
#   adding: content/preds/PRED_086344.tif (deflated 6%)
#   adding: content/preds/PRED_086732.tif (deflated 1%)
#   adding: content/preds/PRED_078783.tif (deflated 2%)
#   adding: content/preds/PRED_090793.tif (deflated 21%)
#   adding: content/preds/PRED_082354.tif (deflated 52%)
#   adding: content/preds/PRED_078102.tif (deflated 2%)
#   adding: content/preds/PRED_080387.tif (deflated 4%)
#   adding: content/preds/PRED_078141.tif (deflated 71%)
#   adding: content/preds/PRED_087370.tif (deflated 71%)
#   adding: content/preds/PRED_085163.tif (deflated 2%)
#   adding: content/preds/PRED_088863.tif (deflated 1%)
#   adding: content/preds/PRED_078117.tif (deflated 1%)
#   adding: content/preds/PRED_092370.tif (deflated 1%)
#   adding: content/preds/PRED_081840.tif (deflated 3%)
#   adding: content/preds/PRED_083121.tif (deflated 8%)
#   adding: content/preds/PRED_081128.tif (deflated 1%)
#   adding: content/preds/PRED_086139.tif (deflated 0%)
#   adding: content/preds/PRED_087772.tif (deflated 71%)
#   adding: content/preds/PRED_077855.tif (deflated 1%)
#   adding: content/preds/PRED_080723.tif (deflated 0%)
#   adding: content/preds/PRED_078044.tif (deflated 8%)
#   adding: content/preds/PRED_086937.tif (deflated 1%)
#   adding: content/preds/PRED_087743.tif (deflated 5%)
#   adding: content/preds/PRED_092390.tif (deflated 2%)
#   adding: content/preds/PRED_084013.tif (deflated 71%)
#   adding: content/preds/PRED_091721.tif (deflated 1%)
#   adding: content/preds/PRED_089960.tif (deflated 17%)
#   adding: content/preds/PRED_080773.tif (deflated 3%)
#   adding: content/preds/PRED_080408.tif (deflated 4%)
#   adding: content/preds/PRED_086952.tif (deflated 1%)
#   adding: content/preds/PRED_089751.tif (deflated 4%)
#   adding: content/preds/PRED_092275.tif (deflated 17%)
#   adding: content/preds/PRED_090693.tif (deflated 2%)
#   adding: content/preds/PRED_090990.tif (deflated 60%)
#   adding: content/preds/PRED_085736.tif (deflated 1%)
#   adding: content/preds/PRED_088419.tif (deflated 1%)
#   adding: content/preds/PRED_081010.tif (deflated 1%)
#   adding: content/preds/PRED_084957.tif (deflated 1%)
#   adding: content/preds/PRED_092069.tif (deflated 1%)
#   adding: content/preds/PRED_091962.tif (deflated 1%)
#   adding: content/preds/PRED_077914.tif (deflated 4%)
#   adding: content/preds/PRED_084529.tif (deflated 0%)
#   adding: content/preds/PRED_089187.tif (deflated 2%)
#   adding: content/preds/PRED_088193.tif (deflated 2%)
#   adding: content/preds/PRED_081430.tif (deflated 4%)
#   adding: content/preds/PRED_090607.tif (deflated 31%)
#   adding: content/preds/PRED_091542.tif (deflated 6%)
#   adding: content/preds/PRED_092416.tif (deflated 1%)
#   adding: content/preds/PRED_088080.tif (deflated 1%)
#   adding: content/preds/PRED_084818.tif (deflated 2%)
#   adding: content/preds/PRED_093204.tif (deflated 14%)
#   adding: content/preds/PRED_093253.tif (deflated 2%)
#   adding: content/preds/PRED_086422.tif (deflated 1%)
#   adding: content/preds/PRED_084587.tif (deflated 71%)
#   adding: content/preds/PRED_079847.tif (deflated 1%)
#   adding: content/preds/PRED_083998.tif (deflated 12%)
#   adding: content/preds/PRED_084590.tif (deflated 1%)
#   adding: content/preds/PRED_091881.tif (deflated 1%)
#   adding: content/preds/PRED_090043.tif (deflated 4%)
#   adding: content/preds/PRED_079515.tif (deflated 4%)
#   adding: content/preds/PRED_091974.tif (deflated 1%)
#   adding: content/preds/PRED_093104.tif (deflated 2%)
#   adding: content/preds/PRED_083303.tif (deflated 4%)
#   adding: content/preds/PRED_080002.tif (deflated 1%)
#   adding: content/preds/PRED_083946.tif (deflated 2%)
#   adding: content/preds/PRED_093180.tif (deflated 1%)
#   adding: content/preds/PRED_092679.tif (deflated 1%)
#   adding: content/preds/PRED_081676.tif (deflated 9%)
#   adding: content/preds/PRED_085279.tif (deflated 42%)
#   adding: content/preds/PRED_087931.tif (deflated 16%)
#   adding: content/preds/PRED_091807.tif (deflated 4%)
#   adding: content/preds/PRED_085540.tif (deflated 1%)
#   adding: content/preds/PRED_082697.tif (deflated 2%)
#   adding: content/preds/PRED_093039.tif (deflated 2%)
#   adding: content/preds/PRED_079127.tif (deflated 0%)
#   adding: content/preds/PRED_090812.tif (deflated 6%)
#   adding: content/preds/PRED_089586.tif (deflated 5%)
#   adding: content/preds/PRED_079785.tif (deflated 16%)
#   adding: content/preds/PRED_085433.tif (deflated 1%)
#   adding: content/preds/PRED_083485.tif (deflated 16%)
#   adding: content/preds/PRED_084328.tif (deflated 31%)
#   adding: content/preds/PRED_078275.tif (deflated 6%)
#   adding: content/preds/PRED_088590.tif (deflated 4%)
#   adding: content/preds/PRED_077875.tif (deflated 2%)
#   adding: content/preds/PRED_089914.tif (deflated 3%)
#   adding: content/preds/PRED_089708.tif (deflated 7%)
#   adding: content/preds/PRED_078116.tif (deflated 2%)
#   adding: content/preds/PRED_077545.tif (deflated 2%)
#   adding: content/preds/PRED_085219.tif (deflated 71%)
#   adding: content/preds/PRED_082058.tif (deflated 2%)
#   adding: content/preds/PRED_083416.tif (deflated 30%)
#   adding: content/preds/PRED_084046.tif (deflated 17%)
#   adding: content/preds/PRED_088114.tif (deflated 1%)
#   adding: content/preds/PRED_090663.tif (deflated 3%)
#   adding: content/preds/PRED_083767.tif (deflated 3%)
#   adding: content/preds/PRED_083651.tif (deflated 0%)
#   adding: content/preds/PRED_092992.tif (deflated 1%)
#   adding: content/preds/PRED_078619.tif (deflated 4%)
#   adding: content/preds/PRED_086505.tif (deflated 1%)
#   adding: content/preds/PRED_084575.tif (deflated 71%)
#   adding: content/preds/PRED_083594.tif (deflated 45%)
#   adding: content/preds/PRED_090206.tif (deflated 28%)
#   adding: content/preds/PRED_085412.tif (deflated 47%)
#   adding: content/preds/PRED_089902.tif (deflated 71%)
#   adding: content/preds/PRED_086267.tif (deflated 9%)
#   adding: content/preds/PRED_087919.tif (deflated 7%)
#   adding: content/preds/PRED_078955.tif (deflated 1%)
#   adding: content/preds/PRED_087542.tif (deflated 71%)
#   adding: content/preds/PRED_082311.tif (deflated 2%)
#   adding: content/preds/PRED_077419.tif (deflated 3%)
#   adding: content/preds/PRED_089802.tif (deflated 4%)
#   adding: content/preds/PRED_080466.tif (deflated 1%)
#   adding: content/preds/PRED_082018.tif (deflated 1%)
#   adding: content/preds/PRED_086087.tif (deflated 2%)
#   adding: content/preds/PRED_088130.tif (deflated 14%)
#   adding: content/preds/PRED_078617.tif (deflated 3%)
#   adding: content/preds/PRED_082162.tif (deflated 12%)
#   adding: content/preds/PRED_088826.tif (deflated 9%)
#   adding: content/preds/PRED_086972.tif (deflated 2%)
#   adding: content/preds/PRED_087657.tif (deflated 49%)
#   adding: content/preds/PRED_087219.tif (deflated 71%)
#   adding: content/preds/PRED_091042.tif (deflated 23%)
#   adding: content/preds/PRED_077422.tif (deflated 2%)
#   adding: content/preds/PRED_079361.tif (deflated 2%)
#   adding: content/preds/PRED_085303.tif (deflated 17%)
#   adding: content/preds/PRED_088439.tif (deflated 1%)
#   adding: content/preds/PRED_087445.tif (deflated 44%)
#   adding: content/preds/PRED_089976.tif (deflated 7%)
#   adding: content/preds/PRED_078458.tif (deflated 18%)
#   adding: content/preds/PRED_092051.tif (deflated 2%)
#   adding: content/preds/PRED_087677.tif (deflated 71%)
#   adding: content/preds/PRED_081700.tif (deflated 2%)
#   adding: content/preds/PRED_083173.tif (deflated 17%)
#   adding: content/preds/PRED_092721.tif (deflated 1%)
#   adding: content/preds/PRED_088678.tif (deflated 1%)
#   adding: content/preds/PRED_085389.tif (deflated 71%)
#   adding: content/preds/PRED_092406.tif (deflated 1%)
#   adding: content/preds/PRED_090717.tif (deflated 35%)
#   adding: content/preds/PRED_081334.tif (deflated 3%)
#   adding: content/preds/PRED_085463.tif (deflated 1%)
#   adding: content/preds/PRED_087122.tif (deflated 29%)
#   adding: content/preds/PRED_092295.tif (deflated 1%)
#   adding: content/preds/PRED_077929.tif (deflated 3%)
#   adding: content/preds/PRED_090877.tif (deflated 23%)
#   adding: content/preds/PRED_085395.tif (deflated 2%)
#   adding: content/preds/PRED_090730.tif (deflated 6%)
#   adding: content/preds/PRED_083162.tif (deflated 54%)
#   adding: content/preds/PRED_082690.tif (deflated 2%)
#   adding: content/preds/PRED_086695.tif (deflated 1%)
#   adding: content/preds/PRED_087179.tif (deflated 50%)
#   adding: content/preds/PRED_081497.tif (deflated 1%)
#   adding: content/preds/PRED_090266.tif (deflated 10%)
#   adding: content/preds/PRED_090857.tif (deflated 42%)
#   adding: content/preds/PRED_081764.tif (deflated 5%)
#   adding: content/preds/PRED_081157.tif (deflated 2%)
#   adding: content/preds/PRED_088827.tif (deflated 6%)
#   adding: content/preds/PRED_090918.tif (deflated 5%)
#   adding: content/preds/PRED_085170.tif (deflated 71%)
#   adding: content/preds/PRED_087735.tif (deflated 1%)
#   adding: content/preds/PRED_084365.tif (deflated 1%)
#   adding: content/preds/PRED_091261.tif (deflated 2%)
#   adding: content/preds/PRED_078095.tif (deflated 2%)
#   adding: content/preds/PRED_077503.tif (deflated 41%)
#   adding: content/preds/PRED_078087.tif (deflated 2%)
#   adding: content/preds/PRED_085189.tif (deflated 5%)
#   adding: content/preds/PRED_085143.tif (deflated 6%)
#   adding: content/preds/PRED_081549.tif (deflated 2%)
#   adding: content/preds/PRED_088295.tif (deflated 3%)
#   adding: content/preds/PRED_090893.tif (deflated 71%)
#   adding: content/preds/PRED_077538.tif (deflated 6%)
#   adding: content/preds/PRED_090597.tif (deflated 71%)
#   adding: content/preds/PRED_083421.tif (deflated 34%)
#   adding: content/preds/PRED_093117.tif (deflated 17%)
#   adding: content/preds/PRED_089230.tif (deflated 70%)
#   adding: content/preds/PRED_092448.tif (deflated 2%)
#   adding: content/preds/PRED_090391.tif (deflated 1%)
#   adding: content/preds/PRED_081373.tif (deflated 1%)
#   adding: content/preds/PRED_088874.tif (deflated 3%)
#   adding: content/preds/PRED_090511.tif (deflated 29%)
#   adding: content/preds/PRED_089538.tif (deflated 2%)
#   adding: content/preds/PRED_089672.tif (deflated 2%)
#   adding: content/preds/PRED_084265.tif (deflated 2%)
#   adding: content/preds/PRED_088582.tif (deflated 3%)
#   adding: content/preds/PRED_079573.tif (deflated 2%)
#   adding: content/preds/PRED_078370.tif (deflated 43%)
#   adding: content/preds/PRED_079336.tif (deflated 5%)
#   adding: content/preds/PRED_092052.tif (deflated 1%)
#   adding: content/preds/PRED_093172.tif (deflated 1%)
#   adding: content/preds/PRED_081471.tif (deflated 71%)
#   adding: content/preds/PRED_087255.tif (deflated 67%)
#   adding: content/preds/PRED_079122.tif (deflated 2%)
#   adding: content/preds/PRED_081347.tif (deflated 5%)
#   adding: content/preds/PRED_091726.tif (deflated 3%)
#   adding: content/preds/PRED_088760.tif (deflated 17%)
#   adding: content/preds/PRED_082198.tif (deflated 49%)
#   adding: content/preds/PRED_085654.tif (deflated 1%)
#   adding: content/preds/PRED_085762.tif (deflated 29%)
#   adding: content/preds/PRED_083091.tif (deflated 40%)
#   adding: content/preds/PRED_084572.tif (deflated 2%)
#   adding: content/preds/PRED_085893.tif (deflated 6%)
#   adding: content/preds/PRED_091519.tif (deflated 37%)
#   adding: content/preds/PRED_085697.tif (deflated 1%)
#   adding: content/preds/PRED_079678.tif (deflated 4%)
#   adding: content/preds/PRED_084697.tif (deflated 1%)
#   adding: content/preds/PRED_082299.tif (deflated 0%)
#   adding: content/preds/PRED_087361.tif (deflated 71%)
#   adding: content/preds/PRED_090508.tif (deflated 71%)
#   adding: content/preds/PRED_089990.tif (deflated 8%)
#   adding: content/preds/PRED_084937.tif (deflated 2%)
#   adding: content/preds/PRED_092735.tif (deflated 2%)
#   adding: content/preds/PRED_092684.tif (deflated 1%)
#   adding: content/preds/PRED_084885.tif (deflated 1%)
#   adding: content/preds/PRED_087707.tif (deflated 1%)
#   adding: content/preds/PRED_080220.tif (deflated 7%)
#   adding: content/preds/PRED_089276.tif (deflated 3%)
#   adding: content/preds/PRED_084352.tif (deflated 4%)
#   adding: content/preds/PRED_081622.tif (deflated 71%)
#   adding: content/preds/PRED_085109.tif (deflated 3%)
#   adding: content/preds/PRED_091929.tif (deflated 2%)
#   adding: content/preds/PRED_078021.tif (deflated 2%)
#   adding: content/preds/PRED_087062.tif (deflated 7%)
